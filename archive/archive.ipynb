# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df1  = pd.read_csv('online_retail_09_10.csv')
df2 = pd.read_csv('online_retail_10_11.csv')

# %%
df = pd.concat([df1,df2],ignore_index=True)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df['revnue'] = df['Quantity'] * df['UnitPrice']

# %%
revenue_per_customer = df.groupby('CustomerID')['revnue'].sum()

# %%
revenue_per_customer
# Out:
# CustomerID
# 12346.0     -64.68
# 12347.0    5633.32
# 12348.0    2019.40
# 12349.0    4404.54
# 12350.0     334.40
#             ...
# 18283.0    2736.65
# 18284.0     436.68
# 18285.0     427.00
# 18286.0    1188.43
# 18287.0    4177.89
# Name: revnue, Length: 5942, dtype: float64

# %%
avarege_per_customer = revenue_per_customer.mean()

# %%
avarege_per_customer
# Out:
# np.float64(2801.7994594412658)

# %%
lifetime_period = 12

# %%
clv = lifetime_period *avarege_per_customer

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067371 entries, 0 to 1067370
# Data columns (total 9 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   InvoiceNo    1067371 non-null  object
#  1   StockCode    1067371 non-null  object
#  2   Description  1062989 non-null  object
#  3   Quantity     1067371 non-null  int64
#  4   InvoiceDate  1067371 non-null  object
#  5   UnitPrice    1067371 non-null  float64
#  6   CustomerID   824364 non-null   float64
#  7   Country      1067371 non-null  object
#  8   revnue       1067371 non-null  float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 73.3+ MB
